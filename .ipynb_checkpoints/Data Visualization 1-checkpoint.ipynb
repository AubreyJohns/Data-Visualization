# %% [markdown]
# Data Visualization

# %%
# import csv
import pandas as pd
cbk_df = pd.read_csv('Key-CBK-Indicative-Exchange-Rates-2015.csv')
gbp = cbk_df[cbk_df['Currency']=='STG POUND']
gbp
# Out:
#             Date   Currency      Mean       Buy      Sell
# 1     02/01/2015  STG POUND  140.9997  140.8611  141.1383
# 22    05/01/2015  STG POUND  138.7694  138.6406  138.8983
# 43    06/01/2015  STG POUND  138.6028  138.4628  138.7428
# 64    07/01/2015  STG POUND  137.6375  137.4972  137.7778
# 85    08/01/2015  STG POUND  137.4622  137.3283  137.5961
# 106   09/01/2015  STG POUND  137.5058  137.3756  137.6361
# 127   12/01/2015  STG POUND  138.2011  138.0939  138.3083
# 148   13/01/2015  STG POUND  138.2797  138.1444  138.4150
# 169   14/01/2015  STG POUND  138.4783  138.3472  138.6094
# 190   15/01/2015  STG POUND  139.1569  139.0456  139.2683
# 211   16/01/2015  STG POUND  138.8336  138.7167  138.9506
# 232   19/01/2015  STG POUND  138.5967  138.4728  138.7206
# 253   20/01/2015  STG POUND  138.1078  137.9811  138.2344
# 274   21/01/2015  STG POUND  138.9467  138.8261  139.0672
# 295   22/01/2015  STG POUND  138.7956  138.6689  138.9222
# 316   23/01/2015  STG POUND  137.4906  137.3600  137.6211
# 337   26/01/2015  STG POUND  137.7183  137.5961  137.8406
# 358   27/01/2015  STG POUND  138.5469  138.4283  138.6656
# 379   28/01/2015  STG POUND  139.0386  138.9244  139.1528
# 400   29/01/2015  STG POUND  138.7536  138.6428  138.8644
# 421   30/01/2015  STG POUND  138.4208  138.3000  138.5417
# 442   02/02/2015  STG POUND  138.2303  138.1044  138.3561
# 463   03/02/2015  STG POUND  137.7058  137.5800  137.8317
# 497   04/02/2015  STG POUND  138.8142  138.6822  138.9461
# 516   05/02/2015  STG POUND  139.1811  139.0583  139.3039
# 528   06/02/2015  STG POUND  140.0900  139.9706  140.2094
# 562   09/02/2015  STG POUND  139.3431  139.2250  139.4611
# 569   10/02/2015  STG POUND  139.6672  139.5433  139.7911
# 594   11/02/2015  STG POUND  139.5364  139.4433  139.6294
# 629   12/02/2015  STG POUND  139.4672  139.3522  139.5822
# ...          ...        ...       ...       ...       ...
# 5231  18/11/2015  STG POUND  155.4169  155.2433  155.5906
# 5252  19/11/2015  STG POUND  155.4642  155.2906  155.6378
# 5273  20/11/2015  STG POUND  156.1628  155.9889  156.3367
# 5294  23/11/2015  STG POUND  155.0594  154.8844  155.2344
# 5315  24/11/2015  STG POUND  154.8850  154.7150  155.0550
# 5336  25/11/2015  STG POUND  154.0528  153.8917  154.2139
# 5357  27/11/2015  STG POUND  154.0406  153.8683  154.2128
# 5378  30/11/2015  STG POUND  153.5583  153.3944  153.7222
# 5399  01/12/2015  STG POUND  153.6514  153.4889  153.8139
# 5420  02/12/2015  STG POUND  154.0458  153.8772  154.2144
# 5441  03/12/2015  STG POUND  153.3778  153.2050  153.5506
# 5462  04/12/2015  STG POUND  153.7625  153.5967  153.9283
# 5483  07/12/2015  STG POUND  154.3722  154.2056  154.5389
# 5518  08/12/2015  STG POUND  153.9361  153.7628  154.1094
# 5525  09/12/2015  STG POUND  152.9653  152.7939  153.1367
# 5546  10/12/2015  STG POUND  154.4936  154.3211  154.6661
# 5567  11/12/2015  STG POUND  154.5836  154.4161  154.7511
# 5601  14/12/2015  STG POUND  155.3103  155.1461  155.4744
# 5615  15/12/2015  STG POUND  154.9467  154.7722  155.1211
# 5630  16/12/2015  STG POUND  153.8142  153.6372  153.9911
# 5651  17/12/2015  STG POUND  152.9294  152.7689  153.0900
# 5672  18/12/2015  STG POUND  152.3289  152.1583  152.4994
# 5693  21/12/2015  STG POUND  152.5578  152.3850  152.7306
# 5714  22/12/2015  STG POUND  152.1603  152.0022  152.3183
# 5735  23/12/2015  STG POUND  151.7953  151.6172  151.9733
# 5756  24/12/2015  STG POUND  152.3814  152.2094  152.5533
# 5777  28/12/2015  STG POUND  152.2714  152.0972  152.4456
# 5798  29/12/2015  STG POUND  152.4067  152.2428  152.5706
# 5819  30/12/2015  STG POUND  151.6767  151.5056  151.8478
# 5840  31/12/2015  STG POUND  151.7978  151.6378  151.9578
#
# [279 rows x 5 columns]

# %%
cbk_df
# Out:
#             Date          Currency      Mean       Buy      Sell
# 0     02/01/2015         US DOLLAR   90.7031   90.6239   90.7822
# 1     02/01/2015         STG POUND  140.9997  140.8611  141.1383
# 2     02/01/2015              EURO  109.3914  109.2844  109.4983
# 3     02/01/2015           SA RAND    7.8066    7.7973    7.8159
# 4     02/01/2015        KES / USHS   30.5944   30.5126   30.6762
# 5     02/01/2015        KES / TSHS   19.1835   19.1117   19.2554
# 6     02/01/2015         KES / RWF    7.5963    7.5455    7.6470
# 7     02/01/2015         KES / BIF   17.1550   17.0298   17.2802
# 8     02/01/2015         AE DIRHAM   24.6939   24.6716   24.7161
# 9     02/01/2015             CAN $   77.8233   77.7354   77.9113
# 10    02/01/2015           S FRANC   90.9486   90.8510   91.0463
# 11    02/01/2015         JPY (100)   75.3598   75.2878   75.4318
# 12    02/01/2015         SW KRONER   11.5900   11.5776   11.6023
# 13    02/01/2015        NOR KRONER   12.1220   12.1106   12.1334
# 14    02/01/2015        DAN KRONER   14.6880   14.6740   14.7021
# 15    02/01/2015         IND RUPEE    1.4330    1.4317    1.4344
# 16    02/01/2015   HONGKONG DOLLAR   11.6949   11.6847   11.7051
# 17    02/01/2015  SINGAPORE DOLLAR   68.3546   68.2717   68.4374
# 18    02/01/2015       SAUDI RIYAL   24.1717   24.1490   24.1944
# 19    02/01/2015      CHINESE YUAN   14.6151   14.5989   14.6314
# 20    02/01/2015      AUSTRALIAN $   73.8504   73.7678   73.9330
# 21    05/01/2015         US DOLLAR   90.7944   90.7056   90.8833
# 22    05/01/2015         STG POUND  138.7694  138.6406  138.8983
# 23    05/01/2015              EURO  108.3936  108.2700  108.5172
# 24    05/01/2015           SA RAND    7.7305    7.7203    7.7407
# 25    05/01/2015        KES / USHS   30.6958   30.6107   30.7809
# 26    05/01/2015        KES / TSHS   19.0541   18.9804   19.1278
# 27    05/01/2015         KES / RWF    7.5886    7.5371    7.6401
# 28    05/01/2015         KES / BIF   17.2921   16.9998   17.5844
# 29    05/01/2015         AE DIRHAM   24.7191   24.6946   24.7436
# ...          ...               ...       ...       ...       ...
# 5830  30/12/2015         SW KRONER   12.2147   12.1991   12.2303
# 5831  30/12/2015        NOR KRONER   11.7746   11.7582   11.7911
# 5832  30/12/2015        DAN KRONER   14.9765   14.9596   14.9934
# 5833  30/12/2015         IND RUPEE    1.5403    1.5387    1.5419
# 5834  30/12/2015   HONGKONG DOLLAR   13.1910   13.1780   13.2040
# 5835  30/12/2015  SINGAPORE DOLLAR   72.2961   72.2120   72.3802
# 5836  30/12/2015       SAUDI RIYAL   27.2596   27.2236   27.2956
# 5837  30/12/2015      CHINESE YUAN   15.7511   15.7318   15.7704
# 5838  30/12/2015      AUSTRALIAN $   74.5157   74.4217   74.6097
# 5839  31/12/2015         US DOLLAR  102.3114  102.2139  102.4088
# 5840  31/12/2015         STG POUND  151.7978  151.6378  151.9578
# 5841  31/12/2015              EURO  111.7833  111.6694  111.8972
# 5842  31/12/2015           SA RAND    6.5768    6.5692    6.5843
# 5843  31/12/2015        KES / USHS   32.9876   32.9073   33.0679
# 5844  31/12/2015        KES / TSHS   21.1121   21.0431   21.1811
# 5845  31/12/2015         KES / RWF    7.3103    7.2691    7.3514
# 5846  31/12/2015         KES / BIF   15.0228   14.9596   15.0860
# 5847  31/12/2015         AE DIRHAM   27.8580   27.8277   27.8884
# 5848  31/12/2015             CAN $   73.7539   73.6730   73.8348
# 5849  31/12/2015           S FRANC  103.4494  103.2985  103.6002
# 5850  31/12/2015         JPY (100)   84.9692   84.8812   85.0572
# 5851  31/12/2015         SW KRONER   12.1641   12.1504   12.1779
# 5852  31/12/2015        NOR KRONER   11.6420   11.6245   11.6595
# 5853  31/12/2015        DAN KRONER   14.9905   14.9751   15.0058
# 5854  31/12/2015         IND RUPEE    1.5418    1.5402    1.5434
# 5855  31/12/2015   HONGKONG DOLLAR   13.1998   13.1872   13.2123
# 5856  31/12/2015  SINGAPORE DOLLAR   72.3816   72.3075   72.4557
# 5857  31/12/2015       SAUDI RIYAL   27.2612   27.2309   27.2916
# 5858  31/12/2015      CHINESE YUAN   15.7528   15.7342   15.7715
# 5859  31/12/2015      AUSTRALIAN $   74.7231   74.6468   74.7994
#
# [5860 rows x 5 columns]

# %%
# check column types
cbk_df.dtypes
# Out:
# Date         object
# Currency     object
# Mean        float64
# Buy         float64
# Sell        float64
# dtype: object

# %%
# Convert column Daate to datetime format
cbk_df['Date'] = pd.to_datetime(cbk_df['Date'])
cbk_df.dtypes
# Out:
# Date        datetime64[ns]
# Currency            object
# Mean               float64
# Buy                float64
# Sell               float64
# dtype: object

# %%
# get earliest date
cbk_df['Date'].min()
# Out:
# Timestamp('2015-01-04 00:00:00')

# %%
cbk_df.describe(include='all')
# Out:
#                        Date      Currency         Mean          Buy  \
# count                  5860          5860  5860.000000  5860.000000
# unique                  254            21          NaN          NaN
# top     2015-12-04 00:00:00  AUSTRALIAN $          NaN          NaN
# freq                    357           280          NaN          NaN
# first   2015-01-04 00:00:00           NaN          NaN          NaN
# last    2015-12-31 00:00:00           NaN          NaN          NaN
# mean                    NaN           NaN    46.206476    46.144874
# std                     NaN           NaN    42.218772    42.183095
# min                     NaN           NaN     1.431800     1.430200
# 25%                     NaN           NaN    12.680550    12.662325
# 50%                     NaN           NaN    25.089200    25.063550
# 75%                     NaN           NaN    77.510800    77.428175
# max                     NaN           NaN   163.818600   163.661100
#
#                Sell
# count   5860.000000
# unique          NaN
# top             NaN
# freq            NaN
# first           NaN
# last            NaN
# mean      46.268075
# std       42.254481
# min        1.433300
# 25%       12.693850
# 50%       25.114850
# 75%       77.593450
# max      163.976100

# %%
cbk_df['Currency'].unique()
# Out:
# array(['US DOLLAR', 'STG POUND', 'EURO', 'SA RAND', 'KES / USHS',
#        'KES / TSHS', 'KES / RWF', 'KES / BIF', 'AE DIRHAM', 'CAN $',
#        'S FRANC', 'JPY (100)', 'SW KRONER', 'NOR KRONER', 'DAN KRONER',
#        'IND RUPEE', 'HONGKONG DOLLAR', 'SINGAPORE DOLLAR', 'SAUDI RIYAL',
#        'CHINESE YUAN', 'AUSTRALIAN $'], dtype=object)

# %%
# Initial capital
capital = 1000000

# %%
# get row for CHINESE YUAN on 16/02/2015
cbk_df_buy=cbk_df[(cbk_df['Currency']=='CHINESE YUAN') & (cbk_df['Date']=='16/02/2015')]
cbk_df_buy
# Out:
#           Date      Currency     Mean      Buy     Sell
# 671 2015-02-16  CHINESE YUAN  14.6542  14.6419  14.6665

# %%
# get cost of buying CHINESE YUAN on 16/02/2015
cbk_df_b=cbk_df_buy['Buy']
cbk_df_b
# Out:
# 671    14.6419
# Name: Buy, dtype: float64

# %%
# get row for CHINESE YUAN on 25/09/2015
cbk_df_sell=cbk_df[(cbk_df['Currency']=='CHINESE YUAN') & (cbk_df['Date']=='25/09/2015')]
cbk_df_sell
# Out:
#            Date      Currency     Mean      Buy     Sell
# 4451 2015-09-25  CHINESE YUAN  16.5113  16.4929  16.5296

# %%
# get cost of selling CHINESE YUAN on 25/09/2015
cbk_df_s=cbk_df_sell['Sell']
cbk_df_s
# Out:
# 4451    16.5296
# Name: Sell, dtype: float64

# %%
# get value of capital in CHINESE YUAN after buying
buy = capital/int(cbk_df_b)
buy
# Out:
# 71428.57142857143

# %%
# get value in Kenya shillings after sale 
sell = int(cbk_df_s) * buy
sell
# Out:
# 1142857.142857143

# %%
# calculate profit made
profit = sell - capital
profit
# Out:
# 142857.14285714296

# %%
# import Matplotlib
import matplotlib.pyplot as plt

# %%
# plot mean price of GBP
plt.plot(gbp['Date'], gbp['Mean'])
plt.title('Plot of GBP Mean price in 2015')
plt.ylabel('Price')
plt.xlabel('Mean')
# Out:
# Text(0.5, 0, 'Mean')

# %%
# plot mean price of GBP
plt.plot(gbp['Date'], gbp['Mean'])
plt.title('Plot of GBP Mean price in 2015')
plt.xlabel('Mean')
plt.xticks(rotation = 90)
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
# plot mean price of GBP
plt.plot(gbp['Date'], gbp['Mean'], linestyle = '--', marker = '+')
plt.title('Plot of GBP Mean price in 2015')
plt.ylabel('Price')
plt.xlabel('Mean')
# Out:
# Text(0.5, 0, 'Mean')

# %%
sample_df = cbk_df[cbk_df['Date']== '2015-10-11']
sample_df = sample_df.iloc[:5,:]
sample_df
# Out:
#            Date    Currency      Mean       Buy      Sell
# 5083 2015-10-11   US DOLLAR  102.2443  102.1444  102.3441
# 5084 2015-10-11   STG POUND  154.2539  154.0806  154.4272
# 5085 2015-10-11        EURO  109.8417  109.7172  109.9661
# 5086 2015-10-11     SA RAND    7.1357    7.1265    7.1448
# 5087 2015-10-11  KES / USHS   33.3027   33.2213   33.3841

# %%
plt.bar(x=sample_df['Currency'], height=sample_df['Mean'])
plt.title('Mean Prices on 11th October')
plt.ylabel('Price')
plt.xlabel('Currency')
# Out:
# Text(0.5, 0, 'Currency')

# %%
sample_df = cbk_df[cbk_df['Date'] == '2015-10-11'].iloc[:5,:]
sample_df
# Out:
#            Date    Currency      Mean       Buy      Sell
# 5083 2015-10-11   US DOLLAR  102.2443  102.1444  102.3441
# 5084 2015-10-11   STG POUND  154.2539  154.0806  154.4272
# 5085 2015-10-11        EURO  109.8417  109.7172  109.9661
# 5086 2015-10-11     SA RAND    7.1357    7.1265    7.1448
# 5087 2015-10-11  KES / USHS   33.3027   33.2213   33.3841

# %%
capit = 1000000
sample_df_buy = capit / sample_df['Buy']
sample_df_buy
# Out:
# 5083      9790.061912
# 5084      6490.109722
# 5085      9114.341234
# 5086    140321.335859
# 5087     30101.170032
# Name: Buy, dtype: float64

# %%
sample_df_sell = sample_df_buy * sample_df['Sell']
sample_df_sell
# Out:
# 5083    1.001955e+06
# 5084    1.002249e+06
# 5085    1.002269e+06
# 5086    1.002568e+06
# 5087    1.004900e+06
# dtype: float64

# %%
profit = sample_df_sell - capit
profit
# Out:
# 5083    1955.075364
# 5084    2249.472030
# 5085    2268.559533
# 5086    2567.880446
# 5087    4900.470481
# dtype: float64

# %%
sample_df['Proportion'] = sample_df['Sell'] / sum(sample_df['Sell'])
sample_df
# Out:
#            Date    Currency      Mean       Buy      Sell  Proportion
# 5083 2015-10-11   US DOLLAR  102.2443  102.1444  102.3441    0.251295
# 5084 2015-10-11   STG POUND  154.2539  154.0806  154.4272    0.379180
# 5085 2015-10-11        EURO  109.8417  109.7172  109.9661    0.270010
# 5086 2015-10-11     SA RAND    7.1357    7.1265    7.1448    0.017543
# 5087 2015-10-11  KES / USHS   33.3027   33.2213   33.3841    0.081971

# %%
# Pie Chart
labels = sample_df['Currency']
sizes = sample_df['Proportion']
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','blue']

plt.pie(sizes, labels=labels, colors=colors,autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Proportion of Currencies in the Sample')
plt.axis('equal')
plt.show()

# %%
# GBP Histogram
x = gbp['Mean']

# %%
plt.hist(x, bins = 17)
plt.title('GBP Histogram')
plt.ylabel('Frequency')
plt.xlabel('Mean')
# Out:
# Text(0.5, 0, 'Mean')

# %%
# histogram bins automatically calculated
plt.hist(x)
plt.title('GBP Histogram')
plt.ylabel('Frequency')
plt.xlabel('Mean')
# Out:
# Text(0.5, 0, 'Mean')

# %%
# scatter plot
import numpy as np
buy = gbp['Buy']
sell = gbp['Sell']

plt.scatter(buy, sell)
plt.title('Scatter of GBPs buy and sell')
plt.xlabel('buy')
plt.ylabel('sell')
plt.show()

# %%
plt.scatter(sample_df['Buy'], sample_df['Sell'])
plt.title('Buy and sellscatter plot of Sample')
plt.xlabel('buy')
plt.ylabel('sell')
plt.show()

# %%
# get dataframe for US DCHINESE YUAN on 16/02/2015
a_buy=cbk_df[((cbk_df['Currency']=='CHINESE YUAN') | (cbk_df['Currency']=='STG POUND') | (cbk_df['Currency']=='EURO') | (cbk_df['Currency']=='JPY (100)') | (cbk_df['Currency']=='US DOLLAR'))  & (cbk_df['Date']=='21/01/2015')]
a_buy
# Out:
#           Date      Currency      Mean       Buy      Sell
# 273 2015-01-21     US DOLLAR   91.6342   91.5578   91.7106
# 274 2015-01-21     STG POUND  138.9467  138.8261  139.0672
# 275 2015-01-21          EURO  106.1136  106.0178  106.2094
# 284 2015-01-21     JPY (100)   77.7813   77.7099   77.8528
# 292 2015-01-21  CHINESE YUAN   14.7417   14.7284   14.7549

# %%
# get dataframe for US DCHINESE YUAN on 16/02/2015
a_sell=cbk_df[((cbk_df['Currency']=='CHINESE YUAN') | (cbk_df['Currency']=='STG POUND') | (cbk_df['Currency']=='EURO') | (cbk_df['Currency']=='JPY (100)') | (cbk_df['Currency']=='US DOLLAR'))  & (cbk_df['Date']=='20/11/2015')]
a_sell
# Out:
#            Date      Currency      Mean       Buy      Sell
# 5272 2015-11-20     US DOLLAR  102.2011  102.1011  102.3012
# 5273 2015-11-20     STG POUND  156.1628  155.9889  156.3367
# 5274 2015-11-20          EURO  109.5069  109.3839  109.6300
# 5283 2015-11-20     JPY (100)   83.1817   83.0833   83.2800
# 5291 2015-11-20  CHINESE YUAN   16.0115   15.9945   16.0284

# %%
bought = a_buy['Buy']
bought
# Out:
# 273     91.5578
# 274    138.8261
# 275    106.0178
# 284     77.7099
# 292     14.7284
# Name: Buy, dtype: float64

# %%
sold = a_sell['Sell']
sold
# Out:
# 5272    102.3012
# 5273    156.3367
# 5274    109.6300
# 5283     83.2800
# 5291     16.0284
# Name: Sell, dtype: float64

# %%
import numpy as np
bought_nump = np.array(bought)
sold_nump = np.array(sold)
profit = sold_nump - bought_nump
profit_pd = pd.DataFrame(profit)
profit_pd
# Out:
#          0
# 0  10.7434
# 1  17.5106
# 2   3.6122
# 3   5.5701
# 4   1.3000

# %%
profit_pd.max()
# Out:
# 0    17.5106
# dtype: float64

# %%
profit_pd.min()
# Out:
# 0    1.3
# dtype: float64

# %%
plt.bar(x=a_buy['Currency'], height=profit_pd[0])
plt.title('Profits in each currency')
plt.ylabel('Profits')
plt.xlabel('Currency')
# Out:
# Text(0.5, 0, 'Currency')
